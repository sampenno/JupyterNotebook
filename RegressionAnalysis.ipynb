# %% [markdown]
# ## Relationships in Linear Regression
# #### It is important to know how the relationship between the values of the x-axis and the values of the y-axis is, if there are no relationship the linear regression can not be used to predict anything.
#
# #### This relationship - the coefficient of correlation - is called r.
#
# #### The r value ranges from -1 to 1, where 0 means no relationship, and 1 (and -1) means 100% related.
#
# #### Python and the Scipy module will compute this value for you, all you have to do is feed it with the x and y values.
#
# #### In the following exmaple we will see how well the data fits a linear regression line.

# %%
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

print(r)
# Out:
# -0.758591524376155

# %% [markdown]
# #### This result indcates that the data is reasonably well correlated, and that we could use linear regression to predict the y value from the x value.
#
# # Predicting Future Values
# #### Now we can use the information we have gathered to predict future values.
#
# #### Example: Let us try to predict the speed of a 10 years old car.
#
# #### To do this, we need the create the same myfunc() function from the previous example.

# %%
from scipy import stats
from matplotlib import pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6] # age or car
y = [99,86,87,88,111,86,103,87,94,78,77,85,86] # speed of car

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept #creates line of best fit

speed = myfunc(10)

print(speed)

mymodel = list(map(myfunc, x)) # Run each value of the x array through the function. This will result in a new array with new values for the y-axis:
# Out:
# 85.59308314937454

# %%
plt.scatter(x, y) # Draw the original scatter plot:
plt.plot(x, mymodel) # Draw the line of linear regression:
plt.show() # Display the diagram containing both the scatter plot and the line of best fit

# %% [markdown]
# ### We could have just used the graph to predict the speed of a 10 years old car.
#
# # Bad Fit?
# #### Let us create an example where linear regression would not be the best method to predict future values.
#
# #### The values given should not produce a good fit, and the r value should be close to 0.

# %%
import matplotlib.pyplot as plt
from scipy import stats

x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

print (r)
# Out:
# 0.01331814154297491

# %% [markdown]
# #### The since the result is close to zero this indicates a very bad relationship, and tells us that this data set is not suitable for linear regression.

# %%
plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()
