# %%
import pandas
import matplotlib.pyplot as plt
import numpy
from sklearn.metrics import r2_score


x = [-4.66226,-4.31656,-4.21398,-3.94966,-3.57855,-3.45571,-3.10844,-3.0813,-2.67246,-2.65229]
y = [41.84298632027783,34.661119537360234,39.38300087682567,37.53984488250128,32.28453118789761,30.00113847641735,27.90598216805913,26.8351550910427,24.8707984799491,23.8881746460579]

plt.scatter(x, y)
plt.xlabel('Temperature')
plt.ylabel('Ice Cream Sales')
plt.title('Ice Cream Sales vs Temperature')
plt.show()
