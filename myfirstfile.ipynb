# %% [markdown]
# # My first Notebook

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# # Product Analysis

# %%
import pandas as pd

data = {
    'product_ID': range(101,110),
    'Product_Name': ["A","B","C","D", "E", "F", "G","H","I"],
    'Category': ['Electronics', 'Electronics', 'Furniture', 'Clothing', 'Food', 'Lego', 'Clothing', 'Phone', 'Food' ],
    'Price': [299.00, 199.99, 399.99, 59.99, 49.00, 30.00, 59.00, 990.00, 14.99],
    'Stock': [12, 10, 20, 30, 60, 20, 10, 12, 25]
}

df = pd.DataFrame(data)

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Price'], df['Stock'])
plt.show()
